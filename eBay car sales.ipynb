# %% [markdown]
# # Data cleaning with examples: Cleaning eBay used cars data with Pandas

# %%
# Import the neccessary modules for data manipulation and visual representation
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as matplot
import seaborn as sns
# %matplotlib inline

# %%
pd.set_option('display.max_columns', None)  
df = pd.read_csv('autos.csv', encoding='latin-1')
df1 = pd.read_csv('autos.csv', encoding='latin-1')
det = pd.read_csv('cnt_km_year_powerPS_minPrice_maxPrice_avgPrice_sdPrice.csv')

# %% [markdown]
# ## Understanding Data

# %%
df.head(5)
# Out:
#            dateCrawled                            name  seller offerType  \
# 0  2016-03-24 11:52:17                      Golf_3_1.6  privat   Angebot
# 1  2016-03-24 10:58:45            A5_Sportback_2.7_Tdi  privat   Angebot
# 2  2016-03-14 12:52:21  Jeep_Grand_Cherokee_"Overland"  privat   Angebot
# 3  2016-03-17 16:54:04              GOLF_4_1_4__3TÜRER  privat   Angebot
# 4  2016-03-31 17:25:20  Skoda_Fabia_1.4_TDI_PD_Classic  privat   Angebot
#
#    price abtest vehicleType  yearOfRegistration    gearbox  powerPS  model  \
# 0    480   test         NaN                1993    manuell        0   golf
# 1  18300   test       coupe                2011    manuell      190    NaN
# 2   9800   test         suv                2004  automatik      163  grand
# 3   1500   test  kleinwagen                2001    manuell       75   golf
# 4   3600   test  kleinwagen                2008    manuell       69  fabia
#
#    kilometer  monthOfRegistration fuelType       brand notRepairedDamage  \
# 0     150000                    0   benzin  volkswagen               NaN
# 1     125000                    5   diesel        audi                ja
# 2     125000                    8   diesel        jeep               NaN
# 3     150000                    6   benzin  volkswagen              nein
# 4      90000                    7   diesel       skoda              nein
#
#            dateCreated  nrOfPictures  postalCode             lastSeen
# 0  2016-03-24 00:00:00             0       70435  2016-04-07 03:16:57
# 1  2016-03-24 00:00:00             0       66954  2016-04-07 01:46:50
# 2  2016-03-14 00:00:00             0       90480  2016-04-05 12:47:46
# 3  2016-03-17 00:00:00             0       91074  2016-03-17 17:40:17
# 4  2016-03-31 00:00:00             0       60437  2016-04-06 10:17:21

# %%
df.tail(5)
# Out:
#                 dateCrawled                                          name  \
# 371523  2016-03-14 17:48:27                    Suche_t4___vito_ab_6_sitze
# 371524  2016-03-05 19:56:21         Smart_smart_leistungssteigerung_100ps
# 371525  2016-03-19 18:57:12            Volkswagen_Multivan_T4_TDI_7DC_UY2
# 371526  2016-03-20 19:41:08                        VW_Golf_Kombi_1_9l_TDI
# 371527  2016-03-07 19:39:19  BMW_M135i_vollausgestattet_NP_52.720____Euro
#
#         seller offerType  price   abtest vehicleType  yearOfRegistration  \
# 371523  privat   Angebot   2200     test         NaN                2005
# 371524  privat   Angebot   1199     test      cabrio                2000
# 371525  privat   Angebot   9200     test         bus                1996
# 371526  privat   Angebot   3400     test       kombi                2002
# 371527  privat   Angebot  28990  control   limousine                2013
#
#           gearbox  powerPS        model  kilometer  monthOfRegistration  \
# 371523        NaN        0          NaN      20000                    1
# 371524  automatik      101       fortwo     125000                    3
# 371525    manuell      102  transporter     150000                    3
# 371526    manuell      100         golf     150000                    6
# 371527    manuell      320      m_reihe      50000                    8
#
#        fuelType           brand notRepairedDamage          dateCreated  \
# 371523      NaN  sonstige_autos               NaN  2016-03-14 00:00:00
# 371524   benzin           smart              nein  2016-03-05 00:00:00
# 371525   diesel      volkswagen              nein  2016-03-19 00:00:00
# 371526   diesel      volkswagen               NaN  2016-03-20 00:00:00
# 371527   benzin             bmw              nein  2016-03-07 00:00:00
#
#         nrOfPictures  postalCode             lastSeen
# 371523             0       39576  2016-04-06 00:46:52
# 371524             0       26135  2016-03-11 18:17:12
# 371525             0       87439  2016-04-07 07:15:26
# 371526             0       40764  2016-03-24 12:45:21
# 371527             0       73326  2016-03-22 03:17:10

# %%
df.columns
# Out:
# Index(['dateCrawled', 'name', 'seller', 'offerType', 'price', 'abtest',
#        'vehicleType', 'yearOfRegistration', 'gearbox', 'powerPS', 'model',
#        'kilometer', 'monthOfRegistration', 'fuelType', 'brand',
#        'notRepairedDamage', 'dateCreated', 'nrOfPictures', 'postalCode',
#        'lastSeen'],
#       dtype='object')

# %% [markdown]
# ## Removing obvious inconsistencies
# ### Deleting columns

# %%
# finding rows where seller is not labels 'privat'
df.loc[df['seller'] != 'privat'].shape
# Out:
# (3, 20)

# %%
df.loc[df['offerType'] != 'Angebot'].shape
# Out:
# (12, 20)

# %% [markdown]
# Since only 3 rows out of the whole dataset has "gewerblich" (commercial) as seller type, we can drop the seller colum. There are other unnecessary or unuseful columns. For example, due to inconsistencies in name labels and the fact that we're not doing a linguistic analysis, we can delete the name column, which takes up a lot of space.

# %%
df = df.drop(['seller','name'],axis=1)
df.head(3)
# Out:
#            dateCrawled offerType  price abtest vehicleType  \
# 0  2016-03-24 11:52:17   Angebot    480   test         NaN
# 1  2016-03-24 10:58:45   Angebot  18300   test       coupe
# 2  2016-03-14 12:52:21   Angebot   9800   test         suv
#
#    yearOfRegistration    gearbox  powerPS  model  kilometer  \
# 0                1993    manuell        0   golf     150000
# 1                2011    manuell      190    NaN     125000
# 2                2004  automatik      163  grand     125000
#
#    monthOfRegistration fuelType       brand notRepairedDamage  \
# 0                    0   benzin  volkswagen               NaN
# 1                    5   diesel        audi                ja
# 2                    8   diesel        jeep               NaN
#
#            dateCreated  nrOfPictures  postalCode             lastSeen
# 0  2016-03-24 00:00:00             0       70435  2016-04-07 03:16:57
# 1  2016-03-24 00:00:00             0       66954  2016-04-07 01:46:50
# 2  2016-03-14 00:00:00             0       90480  2016-04-05 12:47:46

# %%
df.shape
# Out:
# (371528, 18)

# %% [markdown]
# ### Deleting Rows

# %% [markdown]
# #### Invalid values

# %%
# Counting the number of rows with NaN values
np.count_nonzero(df.isnull().values)
# Out:
# 184008

# %%
# there are many ways to find the # of rows with NaN or missing values
# in this case, we have 110572 car sale entries with NaN values
df1 = df[df.isnull().any(axis=1)] # axis=1 specifies rows instead of columns
df1.shape
# Out:
# (110572, 18)

# %%
df = df.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)
df.shape
# Out:
# (260956, 18)

# %% [markdown]
# #### Model and Brand
# Dropping rows where model and brand are not specified

# %%
df.dropna(subset=['model','brand'],axis=0, how='any', thresh=None, inplace=False).head(5)
# Out:
#            dateCrawled offerType  price abtest vehicleType  \
# 3  2016-03-17 16:54:04   Angebot   1500   test  kleinwagen
# 4  2016-03-31 17:25:20   Angebot   3600   test  kleinwagen
# 5  2016-04-04 17:36:23   Angebot    650   test   limousine
# 6  2016-04-01 20:48:51   Angebot   2200   test      cabrio
# 7  2016-03-21 18:54:38   Angebot      0   test   limousine
#
#    yearOfRegistration  gearbox  powerPS    model  kilometer  \
# 3                2001  manuell       75     golf     150000
# 4                2008  manuell       69    fabia      90000
# 5                1995  manuell      102      3er     150000
# 6                2004  manuell      109  2_reihe     150000
# 7                1980  manuell       50   andere      40000
#
#    monthOfRegistration fuelType       brand notRepairedDamage  \
# 3                    6   benzin  volkswagen              nein
# 4                    7   diesel       skoda              nein
# 5                   10   benzin         bmw                ja
# 6                    8   benzin     peugeot              nein
# 7                    7   benzin  volkswagen              nein
#
#            dateCreated  nrOfPictures  postalCode             lastSeen
# 3  2016-03-17 00:00:00             0       91074  2016-03-17 17:40:17
# 4  2016-03-31 00:00:00             0       60437  2016-04-06 10:17:21
# 5  2016-04-04 00:00:00             0       33775  2016-04-06 19:17:07
# 6  2016-04-01 00:00:00             0       67112  2016-04-05 18:18:39
# 7  2016-03-21 00:00:00             0       19348  2016-03-25 16:47:58

# %% [markdown]
# #### Order Type

# %%
df.loc[df['offerType'] != 'Angebot','offerType'].values
# Out:
# array(['Gesuch', 'Gesuch', 'Gesuch', 'Gesuch'], dtype=object)

# %% [markdown]
# Since there are only 12 cars that are not transacted with the order type 'angebot' (offering) and we don't care about 'gesuch' or petitioned cars, we can delete the rows as well as the order type column offerType.

# %%
df = df.loc[df['offerType'] == 'Angebot']
df = df.drop('offerType',axis=1)
df.shape
# Out:
# (260952, 17)

# %% [markdown]
# #### Horsepower
# Since all cars are built with the ability to move, we can consider 0 to be invalid for powerPS too.

# %%
df = df[df.powerPS != 0]
df.dropna(subset=['powerPS'],axis=0, how='any', thresh=None, inplace=False)
df.shape
# Out:
# (251154, 17)

# %% [markdown]
# ### Cleaned data
#
# As we can see, now that the data

# %%
df.head(10)
# Out:
#             dateCrawled  price   abtest vehicleType  yearOfRegistration  \
# 3   2016-03-17 16:54:04   1500     test  kleinwagen                2001
# 4   2016-03-31 17:25:20   3600     test  kleinwagen                2008
# 5   2016-04-04 17:36:23    650     test   limousine                1995
# 6   2016-04-01 20:48:51   2200     test      cabrio                2004
# 7   2016-03-21 18:54:38      0     test   limousine                1980
# 10  2016-03-26 19:54:18   2000  control   limousine                2004
# 11  2016-04-07 10:06:22   2799  control       kombi                2005
# 14  2016-03-21 12:57:01  17999  control         suv                2011
# 17  2016-03-20 10:25:19   1750  control  kleinwagen                2004
# 18  2016-03-23 15:48:05   7550     test         bus                2007
#
#       gearbox  powerPS    model  kilometer  monthOfRegistration fuelType  \
# 3     manuell       75     golf     150000                    6   benzin
# 4     manuell       69    fabia      90000                    7   diesel
# 5     manuell      102      3er     150000                   10   benzin
# 6     manuell      109  2_reihe     150000                    8   benzin
# 7     manuell       50   andere      40000                    7   benzin
# 10    manuell      105  3_reihe     150000                   12   benzin
# 11    manuell      140   passat     150000                   12   diesel
# 14    manuell      190   navara      70000                    3   diesel
# 17  automatik       75   twingo     150000                    2   benzin
# 18    manuell      136    c_max     150000                    6   diesel
#
#          brand notRepairedDamage          dateCreated  nrOfPictures  \
# 3   volkswagen              nein  2016-03-17 00:00:00             0
# 4        skoda              nein  2016-03-31 00:00:00             0
# 5          bmw                ja  2016-04-04 00:00:00             0
# 6      peugeot              nein  2016-04-01 00:00:00             0
# 7   volkswagen              nein  2016-03-21 00:00:00             0
# 10       mazda              nein  2016-03-26 00:00:00             0
# 11  volkswagen                ja  2016-04-07 00:00:00             0
# 14      nissan              nein  2016-03-21 00:00:00             0
# 17     renault              nein  2016-03-20 00:00:00             0
# 18        ford              nein  2016-03-23 00:00:00             0
#
#     postalCode             lastSeen
# 3        91074  2016-03-17 17:40:17
# 4        60437  2016-04-06 10:17:21
# 5        33775  2016-04-06 19:17:07
# 6        67112  2016-04-05 18:18:39
# 7        19348  2016-03-25 16:47:58
# 10       96224  2016-04-06 10:45:34
# 11       57290  2016-04-07 10:25:17
# 14        4177  2016-04-06 07:45:42
# 17       65599  2016-04-06 13:16:07
# 18       88361  2016-04-05 18:45:11

# %%
df.tail(10)
# Out:
#                 dateCrawled  price   abtest vehicleType  yearOfRegistration  \
# 371511  2016-03-31 18:50:37   1999  control   limousine                1997
# 371512  2016-03-25 18:48:06   5000     test   limousine                2003
# 371513  2016-03-21 15:36:22   4400  control   limousine                2008
# 371516  2016-04-04 09:57:12   1490  control  kleinwagen                1998
# 371517  2016-03-28 13:48:07   7900     test   limousine                2010
# 371518  2016-04-02 20:37:03   3999     test       kombi                2005
# 371520  2016-03-19 19:53:49   3200  control   limousine                2004
# 371524  2016-03-05 19:56:21   1199     test      cabrio                2000
# 371525  2016-03-19 18:57:12   9200     test         bus                1996
# 371527  2016-03-07 19:39:19  28990  control   limousine                2013
#
#           gearbox  powerPS        model  kilometer  monthOfRegistration  \
# 371511    manuell      150           a3     150000                   12
# 371512  automatik      260     e_klasse     150000                   12
# 371513    manuell      105         leon     150000                    7
# 371516    manuell       50         lupo     150000                    9
# 371517    manuell      140         golf     150000                    7
# 371518    manuell        3          3er     150000                    5
# 371520    manuell      225         leon     150000                    5
# 371524  automatik      101       fortwo     125000                    3
# 371525    manuell      102  transporter     150000                    3
# 371527    manuell      320      m_reihe      50000                    8
#
#        fuelType          brand notRepairedDamage          dateCreated  \
# 371511   benzin           audi              nein  2016-03-31 00:00:00
# 371512   diesel  mercedes_benz                ja  2016-03-25 00:00:00
# 371513   diesel           seat              nein  2016-03-21 00:00:00
# 371516   benzin     volkswagen              nein  2016-04-04 00:00:00
# 371517   diesel     volkswagen              nein  2016-03-28 00:00:00
# 371518   diesel            bmw              nein  2016-04-02 00:00:00
# 371520   benzin           seat                ja  2016-03-19 00:00:00
# 371524   benzin          smart              nein  2016-03-05 00:00:00
# 371525   diesel     volkswagen              nein  2016-03-19 00:00:00
# 371527   benzin            bmw              nein  2016-03-07 00:00:00
#
#         nrOfPictures  postalCode             lastSeen
# 371511             0        4275  2016-04-06 12:46:41
# 371512             0       90473  2016-04-07 00:44:51
# 371513             0       45896  2016-04-06 15:45:01
# 371516             0       48653  2016-04-06 11:17:13
# 371517             0       75223  2016-04-02 18:16:20
# 371518             0       81825  2016-04-06 20:47:12
# 371520             0       96465  2016-03-19 20:44:43
# 371524             0       26135  2016-03-11 18:17:12
# 371525             0       87439  2016-04-07 07:15:26
# 371527             0       73326  2016-03-22 03:17:10
